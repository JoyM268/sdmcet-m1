# %%
#to plot the Cardiods r = a(1+cosθ) and r = a(1-cosθ) and taking 0<=θ<=2π with step size of 0.01
import matplotlib.pyplot as plt
import numpy as np
a=3
theta = np.arange(0,2*np.pi,0.01)  
r1 = a+(a*np.cos(theta))
r2 = a-(a*np.cos(theta))
plt.polar(theta,r1,theta,r2)
plt.show()
