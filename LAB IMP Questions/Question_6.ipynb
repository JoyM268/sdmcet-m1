# %%
#Expand sin(x) as Taylor series about x = pi / 2 upto 3rd degree term. Also find sin(100 deg)

import numpy as np
from matplotlib import pyplot as plt 
from sympy import *
# %matplotlib inline
x=Symbol('x')

y = sin(x) 
format

x0=float(pi / 2)
dy=diff(y,x)
d2y=diff(y,x,2)
d3y=diff(y,x,3)

yat=lambdify(x,y) 
dyat=lambdify(x,dy)
d2yat=lambdify(x,d2y)
d3yat=lambdify(x,d3y)

y=yat(x0)+(x-x0)*dyat(x0)+((x-x0)**2/2)*d2yat(x0)+((x-x0)**3/6)*d3yat(x0)

print(simplify(y))
yat=lambdify(x, y)
print("\n%.3f" %yat(pi/2+10*(pi/180)))
def f(x):
    return np.sin(x)
x=np.linspace(-10,10)
plt.plot(x, yat(x), color='red')
plt.plot (x, f(x), color='green') 
plt.ylim([-3, 3])
plt.grid()
plt.show()
# Out:
# -1.02053899928946e-17*x**3 - 0.5*x**2 + 1.5707963267949*x - 0.23370055013617
#
# 0.985
